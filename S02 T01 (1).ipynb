# %%
#calculos sencillos
a= 23
b= 25
print(a+b)
print(b-a)
print(b%a)
# Out:
# 48
# 2
# 2

# %% [markdown]
# Los comentarios también los puedo dejar usando markdown

# %% [markdown]
# # Titulo nivel 1
# ## Título nivel 2

# %% [markdown]
# También se puede usar bullets points:
# - item 1
# - item 2
# - item 3

# %% [markdown]
# Se puede poner texto en *cursiva* o en **negrita**

# %% [markdown]
# También se puede insertar imagen:
# ![Captura%20de%20Pantalla%202021-06-10%20a%20la%28s%29%2015.17.38.png](attachment:Captura%20de%20Pantalla%202021-06-10%20a%20la%28s%29%2015.17.38.png)
